# %% [markdown]
# <a href="https://colab.research.google.com/github/alfcastillo90/evaluando_modelos_ml/blob/main/Estructurando_proyecto_de_ciencia_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preguntas propuestas
#
# * ¿Existe una relación entre el número de habitaciones y el precio de las propiedades?
# * ¿Cuál es la distribución de los precios de las propiedades en Melbourne?
# * ¿Cuál es la distribución de los tamaños de terreno y áreas construidas?
# * ¿Cuál es la cantidad promedio de baños y estacionamientos en las propiedades?
# * ¿Hay alguna diferencia en los precios de las propiedades según el tipo (casa, unidad, townhouse, etc.)?
# * ¿Cuál es la distribución de las distancias desde el centro de Melbourne?
# * ¿Existen diferencias en los precios de las propiedades según la región geográfica?
# * ¿Cuál es la proporción de propiedades vendidas mediante diferentes métodos de venta?
# * ¿Hay alguna relación entre el tamaño del terreno y el área construida?
# * ¿Cuál es el agente de bienes raíces más activo en el dataset?

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Instalaciones requeridas

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %% [markdown]
# # Lectura del dataset

# %%
import pandas as pd
path = "/content/gdrive/MyDrive/Estudios/coderhouse/data_science/melb_data.csv";

# %%
dataset = pd.read_csv(path, sep=",")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
# Nombres de las columnas del DataFrame
print("\nNombres de las columnas:")
dataset.columns
# Out:
# Nombres de las columnas:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %% [markdown]
# # Visualizaciones

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualización de la distribución de precios
plt.figure(figsize=(8, 6))
sns.histplot(dataset['Price'], kde=True)
plt.title('Distribución de precios')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.show()

# Resumen numérico básico de la variable "Rooms"
print(dataset['Rooms'].describe())

# Visualización de la relación entre "Rooms" y "Price"
plt.figure(figsize=(8, 6))
sns.boxplot(x='Rooms', y='Price', data=dataset)
plt.title('Relación entre número de habitaciones y precio')
plt.xlabel('Habitaciones')
plt.ylabel('Precio')
plt.show()

# Resumen numérico básico de la variable "Distance"
print(dataset['Distance'].describe())

# Visualización de la distribución de distancias desde el Centro financiero
plt.figure(figsize=(8, 6))
sns.histplot(dataset['Distance'], kde=True)
plt.title('Distribución de distancias desde el Centro financiero')
plt.xlabel('Distancia')
plt.ylabel('Frecuencia')
plt.show()

# Visualización de los tipos de bienes raíces
plt.figure(figsize=(8, 6))
sns.countplot(x='Type', data=dataset)
plt.title('Tipos de bienes raíces')
plt.xlabel('Tipo')
plt.ylabel('Cantidad')
plt.show()

# Resumen numérico básico de la variable "Landsize"
print(dataset['Landsize'].describe())

# Resumen numérico básico de la variable "Bathroom"
print(dataset['Bathroom'].describe())
# Out:
# count    13580.000000
# mean         2.937997
# std          0.955748
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          3.000000
# max         10.000000
# Name: Rooms, dtype: float64
# count    13580.000000
# mean        10.137776
# std          5.868725
# min          0.000000
# 25%          6.100000
# 50%          9.200000
# 75%         13.000000
# max         48.100000
# Name: Distance, dtype: float64
# count     13580.000000
# mean        558.416127
# std        3990.669241
# min           0.000000
# 25%         177.000000
# 50%         440.000000
# 75%         651.000000
# max      433014.000000
# Name: Landsize, dtype: float64
# count    13580.000000
# mean         1.534242
# std          0.691712
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max          8.000000
# Name: Bathroom, dtype: float64

# %% [markdown]
# # Conclusiones
# * ¿Existe una relación entre el número de habitaciones y el precio de las propiedades?
#
# > La visualización de la relación entre el número de habitaciones y el precio a través del boxplot muestra que generalmente hay una tendencia positiva entre estas dos variables. Las propiedades con más habitaciones tienden a tener precios más altos en comparación con aquellas con menos habitaciones.
#
#
# * ¿Cuál es la distribución de los precios de las propiedades en Melbourne?
#
# > La visualización de la distribución de precios muestra que la mayoría de las propiedades se concentran en un rango de precios más bajo, con una distribución sesgada hacia la derecha. Esto sugiere que la mayoría de las propiedades en Melbourne tienen precios relativamente asequibles, pero también hay algunas propiedades de alto valor que pueden influir en la distribución general.
#
# * ¿Cuál es la distribución de los tamaños de terreno y áreas construidas?
#
# > Para obtener información sobre la distribución de los tamaños de terreno y áreas construidas, se puede utilizar una visualización similar a la utilizada para los precios. Esto permitirá observar cómo se distribuyen estos atributos en el dataset y si hay alguna tendencia o patrón en relación con los precios.
#
# * ¿Cuál es la cantidad promedio de baños y estacionamientos en las propiedades?
#
# > Los resúmenes numéricos básicos de las variables "Bathroom" (baños) y "Car" (estacionamientos) proporcionarán información sobre las cantidades promedio y otras estadísticas relevantes. Estos resúmenes permitirán determinar cuántos baños y estacionamientos suelen tener las propiedades en promedio en Melbourne.
#
# * ¿Hay alguna diferencia en los precios de las propiedades según el tipo (casa, unidad, townhouse, etc.)?
#
# > Se puede utilizar una visualización como un boxplot o un gráfico de barras para comparar los precios de las propiedades según el tipo. Esto permitirá identificar si hay diferencias significativas en los precios entre los diferentes tipos de propiedades. Por ejemplo, es posible que las casas tengan precios más altos en comparación con las unidades o los townhouses.
#
# * ¿Cuál es la distribución de las distancias desde el Centro financiero de Melbourne?
#
# > La visualización de la distribución de las distancias desde el Centro financiero mostrará cómo se distribuyen estas distancias en el dataset. Puede revelar si hay áreas en las que las propiedades están más cerca o más lejos del centro de la ciudad, lo que podría influir en los precios.
#
# * ¿Existen diferencias en los precios de las propiedades según la región geográfica?
#
# > Para evaluar las diferencias en los precios de las propiedades según la región geográfica, se puede utilizar una visualización como un boxplot o un gráfico de barras agrupado por regiones. Esto permitirá comparar los precios entre las diferentes regiones y determinar si hay variaciones significativas.
#
# * ¿Cuál es la proporción de propiedades vendidas mediante diferentes métodos de venta?
#
# > La visualización de la proporción de propiedades vendidas según diferentes métodos se puede realizar utilizando un gráfico de barras o un gráfico circular. Esto mostrará la distribución de los métodos de venta y proporcionará información sobre qué métodos son más comunes en el mercado inmobiliario de Melbourne.
#
# * ¿Hay alguna relación entre el tamaño del terreno y el área construida?
#
# > Se puede explorar la relación entre el tamaño del terreno y el área construida utilizando una gráfica de dispersión. Esto permitirá identificar si existe una correlación entre estas dos variables, lo que podría indicar cómo el tamaño del terreno puede influir en el área construida de las propiedades.
#
# * ¿Cuál es el agente de bienes raíces más activo en el dataset?
#
# > La variable "SellerG" representa el agente de bienes raíces. Se puede utilizar una visualización como un gráfico de barras para mostrar los agentes de bienes raíces más activos en términos de la cantidad de propiedades vendidas. Esto permitirá identificar los agentes más prominentes en el mercado inmobiliario de Melbourne.
